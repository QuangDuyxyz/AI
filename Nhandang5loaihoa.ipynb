# %% [markdown]
# <a href="https://colab.research.google.com/github/QuangDuyxyz/AI/blob/main/Nhandang5loaihoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray, save
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder = '/content/drive/MyDrive/ColabNotebooks/Hoa/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('cuc'):
    output = 0
    photo = load_img(folder+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('hong'):
    output = 1
    photo = load_img(folder+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('mai'):
    output = 2
    photo = load_img(folder+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('sen'):
    output = 3
    photo = load_img(folder+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('sung'):
    output = 4
    photo = load_img(folder+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('Nhandang5loaihoa.npy', photos)
save('Nhandang5loaihoa.npy', labels)
# Out:
# (50, 100, 100, 3) (50,)

# %%
print(labels.shape)
labels
photos.shape
# Out:
# (50,)
# (50, 100, 100, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(100,100, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(photos, labels, epochs=9, verbose=1)
# Out:
# Epoch 1/9
# 2/2 [==============================] - 3s 18ms/step - loss: 271.8245 - accuracy: 0.0800
# Epoch 2/9
# 2/2 [==============================] - 0s 15ms/step - loss: 1105.7457 - accuracy: 0.2000
# Epoch 3/9
# 2/2 [==============================] - 0s 16ms/step - loss: 514.0878 - accuracy: 0.1400
# Epoch 4/9
# 2/2 [==============================] - 0s 17ms/step - loss: 232.3894 - accuracy: 0.2000
# Epoch 5/9
# 2/2 [==============================] - 0s 16ms/step - loss: 84.6719 - accuracy: 0.3400
# Epoch 6/9
# 2/2 [==============================] - 0s 15ms/step - loss: 67.2878 - accuracy: 0.3800
# Epoch 7/9
# 2/2 [==============================] - 0s 16ms/step - loss: 19.1542 - accuracy: 0.6000
# Epoch 8/9
# 2/2 [==============================] - 0s 19ms/step - loss: 10.2889 - accuracy: 0.5200
# Epoch 9/9
# 2/2 [==============================] - 0s 13ms/step - loss: 1.4185 - accuracy: 0.7400

# %%
model.evaluate(photos,labels)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5260 - accuracy: 0.8000
# [1.5260053873062134, 0.800000011920929]

# %%
model.save('Nhandang5loaihoa.h5')

# %%
classes = ["cuc","hong","mai","sen","sung"]

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/Hoa/cuc (1).jpg', target_size=(100,100))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 205ms/step
# [[0.12379838 0.11103514 0.10137351 0.1141929  0.10609972 0.0875964
#   0.0867136  0.10075122 0.08977764 0.07866144]]
# 'cuc'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/Hoa/hong (1).jpg', target_size=(100,100))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 60ms/step
# [[0.10248689 0.13197732 0.10660512 0.1041862  0.11504136 0.08865714
#   0.09489255 0.08783963 0.08969682 0.07861696]]
# 'hong'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/Hoa/mai (10).jpg', target_size=(100,100))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[0.11120901 0.11570453 0.11211584 0.11208934 0.11948993 0.08203242
#   0.08744059 0.0918785  0.0862821  0.08175773]]
# 'sung'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/Hoa/sen (1).jpg', target_size=(100,100))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 57ms/step
# [[0.10545861 0.10733644 0.10048392 0.11169779 0.11044569 0.0927036
#   0.09244593 0.09670465 0.09992895 0.08279446]]
# 'sen'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/Hoa/sung (1).jpg', target_size=(100,100))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 33ms/step
# [[0.10167151 0.10398662 0.09903242 0.10972103 0.1203614  0.08861808
#   0.09370351 0.09654859 0.09950198 0.08685485]]
# 'sung'

# %%
from keras.models import load_model
models=load_model('Nhandang5loaihoa.h5')
