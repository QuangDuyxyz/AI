# %% [markdown]
# <a href="https://colab.research.google.com/github/QuangDuyxyz/AI/blob/main/MonanVietNamipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray, save
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder = '/content/drive/MyDrive/ColabNotebooks/MonanVietNam/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('banhmi'):
    output = 0
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhxeo'):
    output = 1
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('bunbo'):
    output = 2
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('bunrieu'):
    output = 3
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('cakho'):
    output = 4
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('che'):
    output = 5
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('comsuon'):
    output = 6
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('hutieu'):
    output = 7
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('trungvitlon'):
    output = 8
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('nemchua'):
    output = 9
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('comchien'):
    output = 9
    photo = load_img(folder+file,target_size=(150,150))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('MonanVietNam.npy', photos)
save('MonanVietNam.npy', labels)
# Out:
# (55, 150, 150, 3) (55,)

# %%
print(labels.shape)
labels
photos.shape
# Out:
# (55,)
# (55, 150, 150, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(photos, labels, epochs=9, verbose=1)
# Out:
# Epoch 1/9
# 2/2 [==============================] - 6s 2s/step - loss: 844.4991 - accuracy: 0.1273
# Epoch 2/9
# 2/2 [==============================] - 3s 1s/step - loss: 1905.5518 - accuracy: 0.1091
# Epoch 3/9
# 2/2 [==============================] - 3s 1s/step - loss: 785.2993 - accuracy: 0.1091
# Epoch 4/9
# 2/2 [==============================] - 3s 1s/step - loss: 350.2834 - accuracy: 0.0909
# Epoch 5/9
# 2/2 [==============================] - 3s 2s/step - loss: 134.0395 - accuracy: 0.2182
# Epoch 6/9
# 2/2 [==============================] - 4s 1s/step - loss: 69.4005 - accuracy: 0.2000
# Epoch 7/9
# 2/2 [==============================] - 3s 1s/step - loss: 20.4937 - accuracy: 0.3455
# Epoch 8/9
# 2/2 [==============================] - 3s 1s/step - loss: 7.7175 - accuracy: 0.4182
# Epoch 9/9
# 2/2 [==============================] - 3s 1s/step - loss: 2.3959 - accuracy: 0.6000

# %%
model.evaluate(photos,labels)
# Out:
# 2/2 [==============================] - 1s 474ms/step - loss: 0.5568 - accuracy: 0.8000
# [0.5568375587463379, 0.800000011920929]

# %%
model.save('10monanVietNam.h5')

# %%
classes = ["banhmi","banhxeo","bunbo","bunrieu","cakho","che","comsuon","hutieu","trungvitlon","nemchua","comchien"]

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/banhmi (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 39ms/step
# [[0.10396207 0.10172859 0.09731589 0.10080118 0.09588333 0.10034598
#   0.1029009  0.10215443 0.09729493 0.0976128 ]]
# 'banhmi'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/banhxeo (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 145ms/step
# [[0.09929401 0.10567532 0.09553588 0.10139558 0.09505367 0.09789538
#   0.10069286 0.10229682 0.10152429 0.10063621]]
# 'banhxeo'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/bunrieu (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 56ms/step
# [[0.09742109 0.09094047 0.0968817  0.12272188 0.08785371 0.09860826
#   0.11522274 0.10406671 0.10103544 0.08524801]]
# 'bunrieu'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/bunbo (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 120ms/step
# [[0.09953044 0.09889735 0.10269922 0.10424446 0.09623376 0.10162388
#   0.10380317 0.10085905 0.09753329 0.09457545]]
# 'bunrieu'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/cakho (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[0.09976392 0.10101118 0.09801964 0.10277853 0.10069095 0.09885771
#   0.09917161 0.10153377 0.09891094 0.09926172]]
# 'bunrieu'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/che (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 125ms/step
# [[0.09970966 0.10300453 0.09813193 0.10210271 0.09628897 0.10040557
#   0.10080417 0.10133561 0.09887379 0.09934302]]
# 'banhxeo'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/comchien (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [[0.09889086 0.10570695 0.09409446 0.10152778 0.09508328 0.09835832
#   0.09992766 0.10258517 0.10043588 0.10338952]]
# 'banhxeo'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/comsuon (2).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 64ms/step
# [[0.10270478 0.10119931 0.09603374 0.10238143 0.09612534 0.1016439
#   0.10770284 0.09802419 0.09834778 0.09583671]]
# 'comsuon'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/hutieu (2).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 115ms/step
# [[0.1088374  0.10087309 0.08637679 0.09622913 0.09062905 0.09905109
#   0.10292836 0.11892489 0.09151025 0.1046399 ]]
# 'hutieu'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/nemchua (1).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [[0.10006663 0.10700761 0.09321123 0.09866345 0.09543336 0.0972851
#   0.09933671 0.10359232 0.09917183 0.10623176]]
# 'banhxeo'

# %%
img = load_img('/content/drive/MyDrive/ColabNotebooks/MonanVietNam/trungvitlon (2).jpg', target_size=(150,150))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 136ms/step
# [[0.09996375 0.10290438 0.09585184 0.10163222 0.09901311 0.09758817
#   0.10221794 0.09763068 0.10565895 0.09753894]]
# 'trungvitlon'

# %%
from keras.models import load_model
models=load_model('10monanVietNam.h5')
